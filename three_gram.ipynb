# %%
import nltk
import numpy as np
import random
import string

import bs4 as bs
import urllib.request
import re
import gensim

# %%
fayl="sd.txt"
myfile = open(fayl, encoding="utf8")
#print(myfile.read())
myfile.seek(0)
article_text=myfile.read()
article_text = article_text.lower()

# %%
print(article_text)
# Out:
# oromimni yo‘qotganman. kechasi-yu kunduzi tinim bilmay sehrli qalpoq axtaraman. ishonsangiz, izlamagan joyim qolmadi. faqat eski qishloqning chekkasidagi tashlandiq bir uy qolgan, xolos. bu hovli kimniki hech kim bilmaydi. hatto, oyim ham aniq bir narsa ayta olmadi.
# kechqurun uyga kirishdan mahrum bo‘lgach, oyim aytyapti deb qo‘shnimizdan ikkita nonni qarzga oldim-da, qorong‘i tushishi bilan o‘sha hovli tomon yo‘l oldim. tashlandiq uydan xunugi bo‘lmas ekan. qaysi burchakka qaramang, ajinami, alvastimi ko‘zini lo‘q qilib menga baqrayib turganga o‘xshaydi. hatto, nazarimda, ikki marta bo‘ri ham ko‘ringandek bo‘ldi. keyin bundoq sinchiklab qarasam, ikkovi ham mushuk ekan. men titkilamagan burchak qolmadi. teshikki bor, hammasiga qo‘l suqib ko‘rdim...
# ...

# %%
article_text = re.sub(r'o‘','ó',article_text)
article_text = re.sub(r'O‘','Ó',article_text)

article_text = re.sub(r'g‘','ġ',article_text)
article_text = re.sub(r'G‘','Ġ',article_text)
article_text = re.sub(r'\’','_',article_text)
article_text = re.sub(r'\'','_',article_text)


#article_text = re.sub(r'\s+','',article_text)
article_text = re.sub(r'[0-9]+', '',article_text)
article_text = re.sub(r'\(','',article_text)
article_text = re.sub(r'\)','',article_text)
article_text = re.sub(r'\*','',article_text)
article_text = re.sub(r'\,','',article_text)
article_text = re.sub(r'\:','',article_text)
article_text = re.sub(r'\;','',article_text)
article_text = re.sub(r'\?','',article_text)
article_text = re.sub(r'\‚','',article_text)
article_text = re.sub(r'\«','',article_text)
article_text = re.sub(r'\»','',article_text)
article_text = re.sub(r'\!','',article_text)
article_text = re.sub(r'\“','',article_text)
article_text = re.sub(r'\”','',article_text)
article_text = re.sub(r'\—','',article_text)
article_text = re.sub(r'\-',' ',article_text)

# %%
my_stopwords = ['agar', 'ajabo', 'albatta', 'allaqachon', 'ammo', 'ana', 'ana u', 'anavi', 'aslida', 'ah', 'ay', 'aytganday', 'aytmasa', 'aytmoqchi', 'balki', 'balkim', 'barcha', 'barchaning', 'barchani', 'barchaga', 'barchada', 'barchadan', 'barchasi', 'bari', 'baribir', 'ba_zan', 'ba_zi', 'bilan', 'bir', 'bir necha', 'bir nechta', 'bir pastda', 'birdaniga', 'birga', 'biri', 'biroq', 'biz', 'bizda', 'bizdan', 'bizga', 'bizlar', 'bizlarda', 'bizlardan', 'bizlarga', 'bizlarni', 'bizlarning', 'bizni', 'bizniki', 'bizlarniki', 'bizning', 'bóladi', 'bólib', 'bólsa', 'bor', 'boshlab', 'boshqa', 'boshqasi', 'bóylab', 'bu', 'bu bilan', 'bu ham', 'bular', 'bunda', 'bundan', 'bunday', 'bunga', 'buni', 'butkul', 'butun', 'chamasi', 'chap', 'chunki', '-da', '-de', 'deb', 'deyarli', 'diya', 'doim', 'edi', 'eh', 'ekan', 'emas', 'emish', 'endi', 'eng', 'esa', 'ey', 'faqat', 'gumbur-gumbur', 'ha', 'hali-beri', 'ham', 'hamma', 'hammasi', 'haqida', 'har', 'har biri', 'har kim', 'har narsa', 'har qachon', 'har qalay', 'har qanday', 'har qaysi', 'har safar', 'har yerda', 'hech', 'hech bir', 'hech bólmasa', 'hech kim', 'hech narsa', 'hech nima', 'hech qachon', 'hech qanday', 'hech qaysi', 'hoy', 'hozir', 'ichida', 'ikki', 'ila', 'ilgari', 'juda', 'kabi', 'kerak', 'keyin', '-ki', 'kim', 'kimdadir', 'kimdir', 'kimgadir', 'kóp', 'kóplab', 'kóproq', 'lekin', 'mana', 'mana bu', 'mana shu', 'manavi', 'maqsadda', 'marta', 'mavjud', 'men', 'menda', 'mendan', 'menga', 'meni', 'meniki', 'mening', '-mi', 'mumkin', 'mumkin emas', 'na', 'nari-beri', 'narsa', 'nechta', 'nega', 'nima', 'nima uchun', 'nimaga', 'oh', 'oh-voh', 'oldin', 'oldinda', 'óng', 'orasida', 'orqali', 'orqasi', 'ósha', 'óshanday', 'óshanga', 'ostida', 'oxirida', 'óy', 'oz', 'óz', 'ózga', 'ózgalar', 'ozgina', 'ózim', 'ózimga', 'ózimiz', 'ózing', 'ózingiz', 'ózlari', 'ózlarimiz', 'ózlaringiz', 'qachon', 'qaerdadir', 'qaerdir', 'qaerga', 'qalay', 'qalt-qalt', 'qalt-qult', 'qancha', 'qanday', 'qaybiri', 'qaerda', 'qaerga', 'qaysi bir', 'qaysi biri', 'qaysiki', 'qaysisi', 'sababi', 'safar', 'sen', 'senda', 'sendan', 'senga', 'seni', 'seniki', 'sening', 'shart-shurt', 'shu', 'shunda ham', 'shundan', 'shundan sóng', 'shunday', 'shunga', 'shuni', 'shuning uchun', 'siz', 'sizda', 'sizdan', 'sizga', 'sizlar', 'sizlarda', 'sizlardan', 'sizlarga', 'sizlarni', 'sizlarning', 'sizni', 'sizniki', 'sizning', 'sóng', 'tagi', 'tagida', 'tars-turs', 'u', 'u ham', 'u-bu', 'uch', 'uchun', 'ular', 'ularda', 'ulardan', 'ularga', 'ularni', 'ularniki', 'ularning', 'unda', 'undan', 'unday', 'unga', 'uni', 'uniki', 'uning', 'ustida', 'va', 'va hakozo', 'va nihoyat', 'voh', 'voy', 'xóp', 'xuddi', 'yalt-yult', 'yana', 'ya_ni', 'yaxshi', 'yaxshiroq', 'yoki', 'yóq', 'zarur', '-ku']
def remove_mystopwords(sentence):
    #tokens = sentence.split(" ")
    tokens = nltk.word_tokenize(sentence)
    tokens_filtered= [word for word in tokens if not word in my_stopwords]
    return (" ").join(tokens_filtered)
article_text = remove_mystopwords(article_text)

# %%
ha', 'qablalmilod', 'qavatiga', 'qadam - baqadam', 'qadamma - qadam', 'bir qadar', 'mumkin qadar', 'qadarli', 'qadim', 'qadimda', 'qadimdan', 'qaybir', 'qayta', 'qaytadan', 'qalban', 'qamti', 'qanaqasiga', 'qanchadan – qancha', 'qardoshlarcha', 'qariyb', 'qas(d)dan', 'qasdma-qasd(i)ga', 'qatorasiga', 'qatorma-qator', 'qatiyan', 'qachonlar', 'qahramonona', 'qiyomatgacha', 'qiyosan', 'qir-qir', 'qisir-qisir', 'qishin-yozin', 'qishloqcha ii', 'qiqir-qiqir', 'qoim', 'qoyim', 'qop-qop', 'qorama-qora', 'qorishiq', 'quyida', 'qullarcha', 'quloqma-quloq', 'qulcha', 'qurqa-pisa', 'qutonlab', 'qushib-chatib', 'quyarda-quymay', 'quqqisdan', 'razilona', 'rasmi', 'rasmona', 'riyokorona', 'rosmana', 'rostakamiga', 'rostdan', 'rustamnamo', 'rustamona', 'rustamcha', 'ruhan', 'ruyirost', 'rupara', 'salkam', 'sal-pal', 'sanatkorona', 'sarosar', 'satta', 'sahar', 'saharlab', 'saharxez', 'sekin', 'sekin-asta', 'sekin-sekin', 'sencha', 'senchalik', 'seriyalab', 'sidirga', 'sidqidil', 'silab-siypab', 'sim-sim', 'sinovchan', 'sinuvchan', 'sira', 'sirasiga', 'sira-sira', 'soatlab', 'sokin', 'soldatcha', 'surbetlarcha', 'surunkasiga', 'suzma-suz', 'suzsiz', 'sumlab', 'sunggi', 'sungra', 'sugin', 'shab-ruz,shab-u ruz', 'shallaqilarcha', 'shap', 'shappa', 'shart', 'shartta', 'shart-shurt', 'sharqiroq', 'shaxdam', 'shaxsan', 'shaxt', 'shaharcha', 'shijoatkorona', 'shilqimlarcha', 'shoirona', 'shosha-pisha', 'shoshib-pishib', 'shoshilinch', 'shu orada (urtada)', 'shunаqаsi', 'shundаy ', 'shundаyin', 'shundаyichа', 'shundаyligichа', 'shundoq', 'shunchа ', 'shunchаyiki', 'shunchаyin', 'shunchаki ', 'shunchаlik ', 'shu-shu', 'tаvridа', 'takroran', 'talay', 'tappa ', 'tamoman', 'tarz', 'bir tarzida', 'tarixan', 'tariqday', 'tarkiban', 'tasmaday, - dek 1', 'tasodifan', 'taq ii', 'taqataq', 'tagin', 'telbalarcha', 'telbanamo', 'telbasaro', 'tenglikda', 'tentaklarcha', 'tergovsiz', 'teskarisiga', 'teskaricha', 'tikkasiga', 'tiklab', 'tiriklay(in)', 'tirikligicha', 'tirishib', 'tirnoqcha 2', 'tiriklay(in)', 'tirikligicha', 'tirishib', 'tirnoqcha 2', 'tongotar', 'turib –turib', 'tuyuqsizdan shv.', 'turalarcha', 'tusat', 'tusatdan', 'tusindan', 'tuxtovsiz', 'tugri', 'tugridan-tugridan', 'tugrilikcha', 'uzalasiga', 'uzzukun', 'uzil-kesil', 'uzluksiz', 'uzoq', 'uzra', 'uzunasiga', 'umidsizlarcha', 'umrbod', '
an', 'chippa', 'chirmamoq', 'chirt ii', 'chirtta', 'chir-chir', 'yuzma-yuz', 'naridan-beri', 'guras-guras', 'nihoyatda', 'noiloj', 'nomma-nom', 'oyda-yilda', 'oldinma-keyin', 'olimona', 'qur-qur', 'guldur-shaldir', 'novatorlarcha', 'odatdagicha', 'ozib-yozib', 'oz-moz', 'ozmuncha', 'oldinda', 'oldindan', 'oldiniga', 'onalarcha', 'ortiq', 'quruqdan-quruq', 'yo bulmasa', 'ammo ', 'ammo-lekin', 'bo', 'ila', 'agar', 'agarda', 'aslo', 'asti', 'axir', 'birgina', 'birdan bir', 'birlan', 'birtagina', 'bittagina', 'bu', 'go`yo', 'go`yoki', 'hali', 'ham', 'hatto', 'hattoki', 'illo-billo', 'modomiki', 'nafaqat', 'naxt', 'nahotki', 'qoq', 'tappa -taxt', 'xup', 'xup-xup', 'yagona']
def remove_mystopwords(sentence):
    #tokens = sentence.split(" ")
    tokens = nltk.word_tokenize(sentence)
    tokens_filtered= [word for word in tokens if not word in my_stopwords]
    return (" ").join(tokens_filtered)
article_text = remove_mystopwords(article_text)

# %%
print(article_text)
# Out:
# oromimni yóqotganman . yu tinim bilmay sehrli qalpoq axtaraman . ishonsangiz izlamagan joyim qolmadi . eski qishloqning chekkasidagi tashlandiq uy qolgan xolos . hovli kimniki bilmaydi . oyim aniq ayta olmadi . uyga kirishdan mahrum bólgach oyim aytyapti qóshnimizdan ikkita nonni qarzga oldim da qoronġi tushishi hovli tomon yól oldim . tashlandiq uydan xunugi bólmas . qaysi burchakka qaramang ajinami alvastimi kózini lóq qilib baqrayib turganga óxshaydi . nazarimda bóri kóringandek bóldi . bundoq sinchiklab qarasam ikkovi mushuk . titkilamagan burchak qolmadi . teshikki hammasiga qól suqib kórdim ... mahal charchab suvsab holdan toyib ótirib qolibman . mudray boshladim . uxlamasligim dedim . órnimdan turib ichkariroq kirdim . molxona oxurda tóp latta yotibdi . orasini titkilagan edim ... topdim ishonasizmi topdim óshaning ózi oq mayin jundan chekkasiga ipakdan chiroyli hoshiya tikilgan salom qalpoqcham qichqirib yubordim . salom hoshimjon degan ovoz eshitildi . axtarib yuruvdim . kut
# ...

# %%
article_text = re.sub(r'[^A-Za-z. ]', '', article_text)
print(article_text)
# Out:
# oromimni yqotganman . yu tinim bilmay sehrli qalpoq axtaraman . ishonsangiz izlamagan joyim qolmadi . eski qishloqning chekkasidagi tashlandiq uy qolgan xolos . hovli kimniki bilmaydi . oyim aniq ayta olmadi . uyga kirishdan mahrum blgach oyim aytyapti qshnimizdan ikkita nonni qarzga oldim da qoroni tushishi hovli tomon yl oldim . tashlandiq uydan xunugi blmas . qaysi burchakka qaramang ajinami alvastimi kzini lq qilib baqrayib turganga xshaydi . nazarimda bri kringandek bldi . bundoq sinchiklab qarasam ikkovi mushuk . titkilamagan burchak qolmadi . teshikki hammasiga ql suqib krdim ... mahal charchab suvsab holdan toyib tirib qolibman . mudray boshladim . uxlamasligim dedim . rnimdan turib ichkariroq kirdim . molxona oxurda tp latta yotibdi . orasini titkilagan edim ... topdim ishonasizmi topdim shaning zi oq mayin jundan chekkasiga ipakdan chiroyli hoshiya tikilgan salom qalpoqcham qichqirib yubordim . salom hoshimjon degan ovoz eshitildi . axtarib yuruvdim . kutib yotuvdim ... bos
# ...

# %%
ngrams = {}
words = 3
#print(len(words_tokens))
#print(len(words_tokens)-words)
words_tokens = nltk.word_tokenize(article_text)
for i in range(len(words_tokens)-words):
    seq = ' '.join(words_tokens[i:i+words])
    
    print(seq)
 #   print(ngrams)
    if  seq not in ngrams.keys():
        ngrams[seq] = []
    ngrams[seq].append(words_tokens[i+words])
# Out:
# oromimni yóqotganman .
# yóqotganman . yu
# . yu tinim
# yu tinim bilmay
# tinim bilmay sehrli
# bilmay sehrli qalpoq
# sehrli qalpoq axtaraman
# qalpoq axtaraman .
# axtaraman . ishonsangiz
# . ishonsangiz izlamagan
# ishonsangiz izlamagan joyim
# izlamagan joyim qolmadi
# joyim qolmadi .
# qolmadi . eski
# . eski qishloqning
# eski qishloqning chekkasidagi
# qishloqning chekkasidagi tashlandiq
# chekkasidagi tashlandiq uy
# tashlandiq uy qolgan
# uy qolgan xolos
# qolgan xolos .
# xolos . hovli
# . hovli kimniki
# hovli kimniki bilmaydi
# kimniki bilmaydi .
# bilmaydi . oyim
# . oyim aniq
# oyim aniq ayta
# aniq ayta olmadi
# ayta olmadi .
# olmadi . uyga
# . uyga kirishdan
# uyga kirishdan mahrum
# kirishdan mahrum bólgach
# mahrum bólgach oyim
# bólgach oyim aytyapti
# oyim aytyapti qóshnimizdan
# aytyapti qóshnimizdan ikkita
# qóshnimizdan ikkita nonni
# ikkita nonni qarzga
# nonni qarzga oldim
# qarzga oldim da
# oldim da qoronġi
# da qoronġi tushishi
# qoronġi tushishi hovli
# ...

# %%
print(ngrams)
# Out:
# {'oromimni yóqotganman .': ['yu'], 'yóqotganman . yu': ['tinim'], '. yu tinim': ['bilmay'], 'yu tinim bilmay': ['sehrli'], 'tinim bilmay sehrli': ['qalpoq'], 'bilmay sehrli qalpoq': ['axtaraman'], 'sehrli qalpoq axtaraman': ['.'], 'qalpoq axtaraman .': ['ishonsangiz'], 'axtaraman . ishonsangiz': ['izlamagan'], '. ishonsangiz izlamagan': ['joyim'], 'ishonsangiz izlamagan joyim': ['qolmadi'], 'izlamagan joyim qolmadi': ['.'], 'joyim qolmadi .': ['eski'], 'qolmadi . eski': ['qishloqning'], '. eski qishloqning': ['chekkasidagi'], 'eski qishloqning chekkasidagi': ['tashlandiq'], 'qishloqning chekkasidagi tashlandiq': ['uy'], 'chekkasidagi tashlandiq uy': ['qolgan'], 'tashlandiq uy qolgan': ['xolos'], 'uy qolgan xolos': ['.'], 'qolgan xolos .': ['hovli'], 'xolos . hovli': ['kimniki'], '. hovli kimniki': ['bilmaydi'], 'hovli kimniki bilmaydi': ['.'], 'kimniki bilmaydi .': ['oyim'], 'bilmaydi . oyim': ['aniq'], '. oyim aniq': ['ayta'], 'oyim aniq ayta': ['olmadi'], 'aniq ayta olmadi': ['.'],
# ...

# %%
curr_sequence = ' '.join(words_tokens[0:words])

# %%
output = curr_sequence
# Out:
# 'oromimni yóqotganman .'

# %%
def most_frequent(List):
    return max(set(List), key = List.count)

for i in range(100):
    if curr_sequence not in ngrams.keys():
        break
    possible_words = ngrams[curr_sequence]
    print("possible_words->")
    print(possible_words)
    print(curr_sequence)
    
    #from collections import Counter
    #counts = Counter(possible_words)
    #maximum_frequncy = max(counts.values())
    #print("counts->")
    #print(maximum_frequncy)
    
    #maximum_frequncy = possible_words.count(max(possible_words))
    
    
    next_word = most_frequent(possible_words)
    #next_word = possible_words[random.randrange(len(possible_words))]
    print("random.randrange(len(possible_words))->")
    print(random.randrange(len(possible_words)))
    
    
    print("next_word->")
    print(next_word)
    
    output += ' ' + next_word
    print("output->")
    print(output)
    
    seq_words = nltk.word_tokenize(output)
    print("seq_words->")
    print(seq_words)
    
    curr_sequence = ' '.join(seq_words[len(seq_words)-words:len(seq_words)])
    print("curr_sequence->")
    print(curr_sequence)
# Out:
# possible_words->
# ['yu']
# oromimni yóqotganman .
# random.randrange(len(possible_words))->
# 0
# next_word->
# yu
# output->
# oromimni yóqotganman . yu
# seq_words->
# ['oromimni', 'yóqotganman', '.', 'yu']
# curr_sequence->
# yóqotganman . yu
# possible_words->
# ['tinim']
# yóqotganman . yu
# random.randrange(len(possible_words))->
# 0
# next_word->
# tinim
# output->
# oromimni yóqotganman . yu tinim
# seq_words->
# ['oromimni', 'yóqotganman', '.', 'yu', 'tinim']
# curr_sequence->
# . yu tinim
# possible_words->
# ['bilmay']
# . yu tinim
# random.randrange(len(possible_words))->
# 0
# next_word->
# bilmay
# output->
# oromimni yóqotganman . yu tinim bilmay
# seq_words->
# ['oromimni', 'yóqotganman', '.', 'yu', 'tinim', 'bilmay']
# curr_sequence->
# yu tinim bilmay
# possible_words->
# ['sehrli']
# yu tinim bilmay
# random.randrange(len(possible_words))->
# 0
# next_word->
# sehrli
# output->
# oromimni yóqotganman . yu tinim bilmay sehrli
# seq_words->
# ...

# %%
print(output)
# Out:
# oromimni yóqotganman . yu tinim bilmay sehrli qalpoq axtaraman . ishonsangiz izlamagan joyim qolmadi . eski qishloqning chekkasidagi tashlandiq uy qolgan xolos . hovli kimniki bilmaydi . oyim aniq ayta olmadi . uyga kirishdan mahrum bólgach oyim aytyapti qóshnimizdan ikkita nonni qarzga oldim da qoronġi tushishi hovli tomon yól oldim . tashlandiq uydan xunugi bólmas . qaysi burchakka qaramang ajinami alvastimi kózini lóq qilib baqrayib turganga óxshaydi . nazarimda bóri kóringandek bóldi . bundoq sinchiklab qarasam ikkovi mushuk . titkilamagan burchak qolmadi . teshikki hammasiga qól suqib kórdim ... mahal charchab suvsab holdan toyib ótirib qolibman . mudray boshladim . uxlamasligim dedim .
